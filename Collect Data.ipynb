# %%
import pandas as pd
import os 
path = os.getcwd()

# %cd C:\Users\Hli\Desktop\MT45_demo\DarwinexLabs-master\tools\Python
from MetaTrader_Helpers.Data_Processing.DWX_HISTORY_IO_v2_0_1_RC8 import DWX_MT_HISTORY_IO
_mt = DWX_MT_HISTORY_IO()
# Out:
# C:\Users\Hli\Desktop\MT45_demo\DarwinexLabs-master\tools\Python

# %%
Data_Directory = r'C:\Users\Hli\AppData\Roaming\MetaQuotes\Terminal\3212703ED955F10C7534BE8497B221F4\history\OANDA-v20 Live-1'
files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(Data_Directory):
    for file in f:
        if '.hst' in file:
            files.append(file)
Cleaned = []        
for file in files:
    Cleaned.append(file[:-4])

# %%
Datas = {}
f_ite = 0
a_ite = 0
for file in Cleaned:
    for i in range(1,7):
        try:
            frequency = int(file[-i:])
            f_ite = frequency
            a_ite = file[:-i]
        except:
            if f_ite in Datas:
                Datas[f_ite].append(a_ite)
            else:
                Datas[f_ite] = [a_ite]
            break

# %%
os.chdir(path)
for Frequency in list(Datas.keys()):
    Assets = Datas[Frequency]
    Historical = pd.DataFrame()
    for asset in Assets:
        temp = _mt._run_(_symbol= asset, _timeframe= Frequency)
        temp['Asset'] = asset
        Historical = pd.concat([Historical, temp])
    Historical = Historical.set_index([Historical.index, 'Asset'])
    Historical = Historical.sort_index(level = 0)
    file_name = str(Frequency) + '_Minutes_Data.csv'
    Historical.to_csv(file_name)

# %%
Temporary_DB = _mt._run_(_symbol= 'SPX500USD', _timeframe= 1440)

# %%
Temporary_DB
# Out:
#                        open    high     low   close  volume  spread  real_volume
# open_time
# 2015-05-05 00:00:00  2113.2  2115.4  2085.2  2089.2   30297       0            0
# 2015-05-06 00:00:00  2089.5  2097.2  2064.8  2078.6   33336       0            0
# 2015-05-07 00:00:00  2078.1  2091.4  2060.6  2087.3   34097       0            0
# 2015-05-08 00:00:00  2087.6  2116.8  2087.6  2111.9   26261       0            0
# 2015-05-11 00:00:00  2113.2  2116.9  2099.1  2100.1   16738       0            0
# 2015-05-12 00:00:00  2100.4  2104.1  2082.5  2098.9   33267       0            0
# 2015-05-13 00:00:00  2099.2  2109.4  2094.7  2099.2   22626       0            0
# 2015-05-14 00:00:00  2099.3  2121.1  2094.9  2120.6   17588       0            0
# 2015-05-15 00:00:00  2120.6  2125.6  2115.9  2121.4   17704       0            0
# 2015-05-18 00:00:00  2122.3  2131.2  2114.9  2129.3   15252       0            0
# 2015-05-19 00:00:00  2129.3  2136.4  2123.8  2126.4   13967       0            0
# 2015-05-20 00:00:00  2126.4  2134.5  2121.8  2124.3   18669       0            0
# 2015-05-21 00:00:00  2124.0  2134.3  2117.6  2131.2   12803       0            0
# 2015-05-22 00:00:00  2131.1  2133.3  2125.1  2126.5   11723       0            0
# 2015-05-25 00:00:00  2126.5  2128.9  2120.6  2125.3    1486       0            0
# 2015-05-26 00:00:00  2125.3  2126.6  2098.0  2107.3   18342       0            0
# 2015-05-27 00:00:00  2107.6  2126.1  2103.2  2121.7   15547       0            0
# 2015-05-28 00:00:00  2122.0  2124.3  2112.0  2124.1   18859       0            0
# 2015-05-29 00:00:00  2124.0  2124.5  2103.6  2108.3   19777       0            0
# 2015-06-01 00:00:00  2108.1  2119.0  2101.7  2112.1   24374       0            0
# 2015-06-02 00:00:00  2112.0  2117.1  2095.5  2108.2   33032       0            0
